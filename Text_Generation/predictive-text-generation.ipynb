# %% [markdown]
# # Text Generation with Neural Networks

# %% [markdown]
# ## Functions for Processing Text
#
# ### Reading in files as a string text

# %%
def read_file(filepath):
    
    with open(filepath) as f:
        str_text = f.read()
    
    return str_text

# %%
read_file('/kaggle/input/sample-text-from-melville-moby-dick/moby_dick_four_chapters.txt')
# Out:
# 'Call me Ishmael.  Some years ago--never mind how long\nprecisely--having little or no money in my purse, and nothing\nparticular to interest me on shore, I thought I would sail about a\nlittle and see the watery part of the world.  It is a way I have of\ndriving off the spleen and regulating the circulation.  Whenever I\nfind myself growing grim about the mouth; whenever it is a damp,\ndrizzly November in my soul; whenever I find myself involuntarily\npausing before coffin warehouses, and bringing up the rear of every\nfuneral I meet; and especially whenever my hypos get such an upper\nhand of me, that it requires a strong moral principle to prevent me\nfrom deliberately stepping into the street, and methodically knocking\npeople\'s hats off--then, I account it high time to get to sea as soon\nas I can.  This is my substitute for pistol and ball.  With a\nphilosophical flourish Cato throws himself upon his sword; I quietly\ntake to the ship.  There is nothing surprising in this.  If they but\nknew it, almost all men in their degree, some time or other, cherish\nvery nearly the same feelings towards the ocean with me.\n\nThere now is your insular city of the Manhattoes, belted round by\nwharves as Indian isles by coral reefs--commerce surrounds it with\nher surf.  Right and left, the streets take you waterward.  Its\nextreme downtown is the battery, where that noble mole is washed by\nwaves, and cooled by breezes, which a few hours previous were out of\nsight of land.  Look at the crowds of water-gazers there.\n\nCircumambulate the city of a dreamy Sabbath afternoon.  Go from\nCorlears Hook to Coenties Slip, and from thence, by Whitehall,\nnorthward.  What do you see?--Posted like silent sentinels all around\nthe town, stand thousands upon thousands of mortal men fixed in ocean\nreveries.  Some leaning against the spiles; some seated upon the\npier-heads; some looking over the bulwarks of ships from China; some\nhigh aloft in the rigging, as if striving to get a still better\nseaward peep.  But these are all landsmen; of week days pent up in\nlath and plaster--tied to counters, nailed to benches, clinched to\ndesks.  How then is this?  Are the green fields gone?  What do they\nhere?\n\nBut look! here come more crowds, pacing straight for the water, and\nseemingly bound for a dive.  Strange!  Nothing will content them but\nthe extremest limit of the land; loitering under the shady lee of\nyonder warehouses will not suffice.  No.  They must get just as nigh\nthe water as they possibly can without falling in.  And there they\nstand--miles of them--leagues.  Inlanders all, they come from lanes\nand alleys, streets and avenues--north, east, south, and west.  Yet\nhere they all unite.  Tell me, does the magnetic virtue of the\nneedles of the compasses of all those ships attract them thither?\n\nOnce more.  Say you are in the country; in some high land of lakes.\nTake almost any path you please, and ten to one it carries you down\nin a dale, and leaves you there by a pool in the stream.  There is\nmagic in it.  Let the most absent-minded of men be plunged in his\ndeepest reveries--stand that man on his legs, set his feet a-going,\nand he will infallibly lead you to water, if water there be in all\nthat region.  Should you ever be athirst in the great American\ndesert, try this experiment, if your caravan happen to be supplied\nwith a metaphysical professor.  Yes, as every one knows, meditation\nand water are wedded for ever.\n\nBut here is an artist.  He desires to paint you the dreamiest,\nshadiest, quietest, most enchanting bit of romantic landscape in all\nthe valley of the Saco.  What is the chief element he employs?  There\nstand his trees, each with a hollow trunk, as if a hermit and a\ncrucifix were within; and here sleeps his meadow, and there sleep his\ncattle; and up from yonder cottage goes a sleepy smoke.  Deep into\ndistant woodlands winds a mazy way, reaching to overlapping spurs of\nmountains bathed in their hill-side  ...

# %% [markdown]
# ### Tokenize and Clean Text

# %%
import spacy
nlp = spacy.load('en_core_web_sm',disable=['parser', 'tagger','ner'])

nlp.max_length = 1198623
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
d = read_file('/kaggle/input/sample-text-from-melville-moby-dick/melville-moby_dick.txt')
tokens = separate_punc(d)
# Out:
# /opt/conda/lib/python3.10/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
tokens
# Out:
# ['chapter',
#  '1',
#  'loomings',
#  'call',
#  'me',
#  'ishmael',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me',
#  'on',
#  'shore',
#  'i',
#  'thought',
#  'i',
#  'would',
#  'sail',
#  'about',
#  'a',
#  'little',
#  'and',
#  'see',
#  'the',
#  'watery',
#  'part',
#  'of',
#  'the',
#  'world',
#  'it',
#  'is',
#  'a',
#  'way',
#  'i',
#  'have',
#  'of',
#  'driving',
#  'off',
#  'the',
#  'spleen',
#  'and',
#  'regulating',
#  'the',
#  'circulation',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'growing',
#  'grim',
#  'about',
#  'the',
#  'mouth',
#  'whenever',
#  'it',
#  'is',
#  'a',
#  'damp',
#  'drizzly',
#  'november',
#  'in',
#  'my',
#  'soul',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'involuntarily',
#  'pausing',
#  'before',
#  'coffin',
#  'warehouses',
#  'and',
#  'bringing',
#  'up',
#  'the',
#  'rear',
#  'of',
#  'every',
#  'funeral',
#  'i',
#  'meet',
#  'and',
#  'especially',
#  'whenever',
#  'my',
#  'hypos',
#  'get',
#  'such',
#  'an',
#  'upper',
#  'hand',
#  'of',
#  'me',
#  'that',
#  'it',
#  'requires',
#  'a',
#  'strong',
#  'moral',
#  'principle',
#  'to',
#  'prevent',
#  'me',
#  'from',
#  'deliberately',
#  'stepping',
#  'into',
#  'the',
#  'street',
#  'and',
#  'methodically',
#  'knocking',
#  'people',
#  "'s",
#  'hats',
#  'off',
#  'then',
#  'i',
#  'account',
#  'it',
#  'high',
#  'time',
#  'to',
#  'get',
#  'to',
#  'sea',
#  'as',
#  'soon',
#  'as',
#  'i',
#  'can',
#  'this',
#  'is',
#  'my',
#  'substitute',
#  'for',
#  'pistol',
#  'and',
#  'ball',
#  'with',
#  'a',
#  'philosophical',
#  'flourish',
#  'cato',
#  'throws',
#  'himself',
#  'upon',
#  'his',
#  'sword',
#  'i',
#  'quietly',
#  'take',
#  'to',
#  'the',
#  'ship',
#  'there',
#  'is',
#  'nothing',
#  'surprising',
#  'in',
#  'this',
#  'if',
#  'they',
#  'but',
#  'knew',
#  'it',
#  'almost',
#  'all',
#  'men',
#  'in',
#  'their',
#  'degree',
#  'some',
#  'time',
#  'or',
#  'other',
#  'cherish',
#  'very',
#  'nearly',
#  'the',
#  'same',
#  'feelings',
#  'towards',
#  'the',
#  'ocean',
#  'with',
#  'me',
#  'there',
#  'now',
#  'is',
#  'your',
#  'insular',
#  'city',
#  'of',
#  'the',
#  'manhattoes',
#  'belted',
#  'round',
#  'by',
#  'wharves',
#  'as',
#  'indian',
#  'isles',
#  'by',
#  'coral',
#  'reefs',
#  'commerce',
#  'surrounds',
#  'it',
#  'with',
#  'her',
#  'surf',
#  'right',
#  'and',
#  'left',
#  'the',
#  'streets',
#  'take',
#  'you',
#  'waterward',
#  'its',
#  'extreme',
#  'downtown',
#  'is',
#  'the',
#  'battery',
#  'where',
#  'that',
#  'noble',
#  'mole',
#  'is',
#  'washed',
#  'by',
#  'waves',
#  'and',
#  'cooled',
#  'by',
#  'breezes',
#  'which',
#  'a',
#  'few',
#  'hours',
#  'previous',
#  'were',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'look',
#  'at',
#  'the',
#  'crowds',
#  'of',
#  'water',
#  'gazers',
#  'there',
#  'circumambulate',
#  'the',
#  'city',
#  'of',
#  'a',
#  'dreamy',
#  'sabbath',
#  'afternoon',
#  'go',
#  'from',
#  'corlears',
#  'hook',
#  'to',
#  'coenties',
#  'slip',
#  'and',
#  'from',
#  'thence',
#  'by',
#  'whitehall',
#  'northward',
#  'what',
#  'do',
#  'you',
#  'see?--posted',
#  'like',
#  'silent',
#  'sentinels',
#  'all',
#  'around',
#  'the',
#  'town',
#  'stand',
#  'thousands',
#  'upon',
#  'thousands',
#  'of',
#  'mortal',
#  'men',
#  'fixed',
#  'in',
#  'ocean',
#  'reveries',
#  'some',
#  'leaning',
#  'against',
#  'the',
#  'spiles',
#  'some',
#  'seated',
#  'upon',
#  'the',
#  'pier',
#  'heads',
#  'some',
#  'looking',
#  'over',
#  'the',
#  'bulwarks',
#  'of',
#  'ships',
#  'from',
#  'china',
#  'some',
#  'high',
#  'aloft',
#  'in',
#  'the',
#  'rigging',
#  'as',
#  'if',
#  'striving',
#  'to',
#  'get',
#  'a',
#  'still',
#  'better',
#  'seaward',
#  'peep',
#  'but',
#  'these',
#  'are',
#  'all',
#  'landsmen',
#  'of',
#  'week',
#  'days',
#  'pent',
#  'up',
#  'in',
#  'lath',
#  'and',
#  'plaster',
#  'tied',
#  'to',
#  'counters',
#  'nailed',
#  'to',
#  'benches',
#  'clinched',
#  'to',
#  'desks',
#  'how',
#  'then',
#  'is',
#  'this',
#  'are',
#  'the',
#  'green',
#  'fields',
#  'gone',
#  'what',
#  'do',
#  'they',
#  'here',
#  'but',
#  'look',
#  'here',
#  'come',
#  'more',
#  'crowds',
#  'pacing',
#  'straight',
#  'for',
#  'the',
#  'water',
#  'and',
#  'seemingly',
#  'bound',
#  'for',
#  'a',
#  'dive',
#  'strange',
#  'nothing',
#  'will',
#  'content',
#  'them',
#  'but',
#  'the',
#  'extremest',
#  'limit',
#  'of',
#  'the',
#  'land',
#  'loitering',
#  'under',
#  'the',
#  'shady',
#  'lee',
#  'of',
#  'yonder',
#  'warehouses',
#  'will',
#  'not',
#  'suffice',
#  'no',
#  'they',
#  'must',
#  'get',
#  'just',
#  'as',
#  'nigh',
#  'the',
#  'water',
#  'as',
#  'they',
#  'possibly',
#  'can',
#  'without',
#  'falling',
#  'in',
#  'and',
#  'there',
#  'they',
#  'stand',
#  'miles',
#  'of',
#  'them',
#  'leagues',
#  'inlanders',
#  'all',
#  'they',
#  'come',
#  'from',
#  'lanes',
#  'and',
#  'alleys',
#  'streets',
#  'and',
#  'avenues',
#  'north',
#  'east',
#  'south',
#  'and',
#  'west',
#  'yet',
#  'here',
#  'they',
#  'all',
#  'unite',
#  'tell',
#  'me',
#  'does',
#  'the',
#  'magnetic',
#  'virtue',
#  'of',
#  'the',
#  'needles',
#  'of',
#  'the',
#  'compasses',
#  'of',
#  'all',
#  'those',
#  'ships',
#  'attract',
#  'them',
#  'thither',
#  'once',
#  'more',
#  'say',
#  'you',
#  'are',
#  'in',
#  'the',
#  'country',
#  'in',
#  'some',
#  'high',
#  'land',
#  'of',
#  'lakes',
#  'take',
#  'almost',
#  'any',
#  'path',
#  'you',
#  'please',
#  'and',
#  'ten',
#  'to',
#  'one',
#  'it',
#  'carries',
#  'you',
#  'down',
#  'in',
#  'a',
#  'dale',
#  'and',
#  'leaves',
#  'you',
#  'there',
#  'by',
#  'a',
#  'pool',
#  'in',
#  'the',
#  'stream',
#  'there',
#  'is',
#  'magic',
#  'in',
#  'it',
#  'let',
#  'the',
#  'most',
#  'absent',
#  'minded',
#  'of',
#  'men',
#  'be',
#  'plunged',
#  'in',
#  'his',
#  'deepest',
#  'reveries',
#  'stand',
#  'that',
#  'man',
#  'on',
#  'his',
#  'legs',
#  'set',
#  'his',
#  'feet',
#  'a',
#  'going',
#  'and',
#  'he',
#  'will',
#  'infallibly',
#  'lead',
#  'you',
#  'to',
#  'water',
#  'if',
#  'water',
#  'there',
#  'be',
#  'in',
#  'all',
#  'that',
#  'region',
#  'should',
#  'you',
#  'ever',
#  'be',
#  'athirst',
#  'in',
#  'the',
#  'great',
#  'american',
#  'desert',
#  'try',
#  'this',
#  'experiment',
#  'if',
#  'your',
#  'caravan',
#  'happen',
#  'to',
#  'be',
#  'supplied',
#  'with',
#  'a',
#  'metaphysical',
#  'professor',
#  'yes',
#  'as',
#  'every',
#  'one',
#  'knows',
#  'meditation',
#  'and',
#  'water',
#  'are',
#  'wedded',
#  'for',
#  'ever',
#  'but',
#  'here',
#  'is',
#  'an',
#  'artist',
#  'he',
#  'desires',
#  'to',
#  'paint',
#  'you',
#  'the',
#  'dreamiest',
#  'shadiest',
#  'quietest',
#  'most',
#  'enchanting',
#  'bit',
#  'of',
#  'romantic',
#  'landscape',
#  'in',
#  'all',
#  'the',
#  'valley',
#  'of',
#  'the',
#  'saco',
#  'what',
#  'is',
#  'the',
#  'chief',
#  'element',
#  'he',
#  'employs',
#  'there',
#  'stand',
#  'his',
#  'trees',
#  'each',
#  'with',
#  'a',
#  'hollow',
#  'trunk',
#  'as',
#  'if',
#  'a',
#  'hermit',
#  'and',
#  'a',
#  'crucifix',
#  'were',
#  'within',
#  'and',
#  'here',
#  'sleeps',
#  'his',
#  'meadow',
#  'and',
#  'there',
#  'sleep',
#  'his',
#  'cattle',
#  'and',
#  'up',
#  'from',
#  'yonder',
#  'cottage',
#  'goes',
#  'a',
#  'sleepy',
#  'smoke',
#  'deep',
#  'into',
#  'distant',
#  'woodlands',
#  'winds',
#  'a',
#  'mazy',
#  'way',
#  'reaching',
#  'to',
#  'overlapping',
#  'spurs',
#  'of',
#  'mountains',
#  'bathed',
#  'in',
#  'their',
#  'hill',
#  'side',
#  'blue',
#  'but',
#  'though',
#  'the',
#  'picture',
#  'lies',
#  'thus',
#  'tranced',
#  'and',
#  'though',
#  'this',
#  'pine',
#  'tree',
#  'shakes',
#  'down',
#  'its',
#  'sighs',
#  'like',
#  'leaves',
#  'upon',
#  'this',
#  'shepherd',
#  "'s",
#  'head',
#  'yet',
#  'all',
#  'were',
#  'vain',
#  'unless',
#  'the',
#  'shepherd',
#  "'s",
#  'eye',
#  'were',
#  'fixed',
#  'upon',
#  'the',
#  'magic',
#  'stream',
#  'before',
#  'him',
#  'go',
#  'visit',
#  'the',
#  'prairies',
#  'in',
#  'june',
#  'when',
#  'for',
#  'scores',
#  'on',
#  'scores',
#  'of',
#  'miles',
#  'you',
#  'wade',
#  'knee',
#  'deep',
#  'among',
#  'tiger',
#  'lilies',
#  'what',
#  'is',
#  'the',
#  'one',
#  'charm',
#  'wanting?--water',
#  'there',
#  'is',
#  'not',
#  'a',
#  'drop',
#  'of',
#  'water',
#  'there',
#  'were',
#  'niagara',
#  'but',
#  'a',
#  'cataract',
#  'of',
#  'sand',
#  'would',
#  'you',
#  'travel',
#  'your',
#  'thousand',
#  'miles',
#  'to',
#  'see',
#  'it',
#  'why',
#  'did',
#  'the',
#  'poor',
#  'poet',
#  'of',
#  'tennessee',
#  'upon',
#  'suddenly',
#  'receiving',
#  'two',
#  'handfuls',
#  'of',
#  'silver',
#  'deliberate',
#  'whether',
#  'to',
#  'buy',
#  'him',
#  'a',
#  'coat',
#  'which',
#  'he',
#  'sadly',
#  'needed',
#  'or',
#  'invest',
#  'his',
#  'money',
#  'in',
#  'a',
#  'pedestrian',
#  'trip',
#  'to',
#  'rockaway',
#  'beach',
#  'why',
#  'is',
#  'almost',
#  'every',
#  'robust',
#  'healthy',
#  'boy',
#  'with',
#  'a',
#  'robust',
#  'healthy',
#  'soul',
#  'in',
#  'him',
#  'at',
#  'some',
#  'time',
#  'or',
#  'other',
#  'crazy',
#  'to',
#  'go',
#  'to',
#  'sea',
#  'why',
#  'upon',
#  'your',
#  'first',
#  'voyage',
#  'as',
#  'a',
#  'passenger',
#  'did',
#  'you',
#  'yourself',
#  'feel',
#  'such',
#  'a',
#  'mystical',
#  'vibration',
#  'when',
#  'first',
#  'told',
#  'that',
#  'you',
#  'and',
#  'your',
#  'ship',
#  'were',
#  'now',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'why',
#  'did',
#  'the',
#  'old',
#  'persians',
#  'hold',
#  'the',
#  'sea',
#  'holy',
#  'why',
#  'did',
#  'the',
#  'greeks',
#  'give',
#  'it',
#  'a',
#  'separate',
#  'deity',
#  'and',
#  'own',
#  'brother',
#  'of',
#  'jove',
#  'surely',
#  'all',
#  'this',
#  'is',
#  'not',
#  'without',
#  'meaning',
#  'and',
#  'still',
#  'deeper',
#  'the',
#  'meaning',
#  'of',
#  'that',
#  'story',
#  'of',
#  'narcissus',
#  'who',
#  'because',
#  'he',
#  'could',
#  'not',
#  'grasp',
#  'the',
#  'tormenting',
#  'mild',
#  'image',
#  'he',
#  'saw',
#  'in',
#  'the',
#  'fountain',
#  'plunged',
#  'into',
#  'it',
#  'and',
#  'was',
#  'drowned',
#  'but',
#  'that',
#  'same',
#  'image',
#  'we',
#  'ourselves',
#  'see',
#  'in',
#  'all',
#  'rivers',
#  'and',
#  'oceans',
#  'it',
#  'is',
#  'the',
#  'image',
#  'of',
#  'the',
#  'ungraspable',
#  'phantom',
#  'of',
#  'life',
#  'and',
#  'this',
#  'is',
#  'the',
#  'key',
#  'to',
#  'it',
#  'all',
#  'now',
#  'when',
#  'i',
#  'say',
#  'that',
#  'i',
#  'am',
#  'in',
#  'the',
#  'habit',
#  'of',
#  'going',
#  'to',
#  'sea',
#  'whenever',
#  'i',
#  'begin',
#  'to',
#  'grow',
#  'hazy',
#  'about',
#  ...]

# %%
len(tokens)
# Out:
# 214708

# %%
4431/25
# Out:
# 177.24

# %% [markdown]
# ## Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %%
' '.join(text_sequences[0])
# Out:
# 'chapter 1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to'

# %%
' '.join(text_sequences[1])
# Out:
# '1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest'

# %%
' '.join(text_sequences[2])
# Out:
# 'loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me'

# %%
len(text_sequences)
# Out:
# 214682

# %% [markdown]
# # Keras

# %% [markdown]
# ### Keras Tokenization

# %%
from keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [158,
#  9443,
#  17526,
#  402,
#  42,
#  1043,
#  43,
#  247,
#  659,
#  140,
#  296,
#  116,
#  82,
#  787,
#  347,
#  113,
#  36,
#  50,
#  1788,
#  6,
#  49,
#  3028,
#  3,
#  218,
#  442,
#  5]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'to',
#  6: 'in',
#  7: 'that',
#  8: 'his',
#  9: 'it',
#  10: 'i',
#  11: 'he',
#  12: 'but',
#  13: "'s",
#  14: 'as',
#  15: 'with',
#  16: 'is',
#  17: 'was',
#  18: 'for',
#  19: 'all',
#  20: 'this',
#  21: 'at',
#  22: 'not',
#  23: 'by',
#  24: 'whale',
#  25: 'from',
#  26: 'so',
#  27: 'him',
#  28: 'on',
#  29: 'be',
#  30: 'one',
#  31: 'you',
#  32: 'there',
#  33: 'now',
#  34: 'had',
#  35: 'have',
#  36: 'or',
#  37: 'were',
#  38: 'they',
#  39: 'like',
#  40: 'which',
#  41: 'then',
#  42: 'me',
#  43: 'some',
#  44: 'their',
#  45: 'what',
#  46: 'when',
#  47: 'an',
#  48: 'are',
#  49: 'my',
#  50: 'no',
#  51: 'upon',
#  52: 'out',
#  53: 'man',
#  54: 'into',
#  55: 'ship',
#  56: 'up',
#  57: 'more',
#  58: 'ahab',
#  59: 'if',
#  60: 'them',
#  61: 'old',
#  62: 'we',
#  63: 'sea',
#  64: 'would',
#  65: "'",
#  66: 'ye',
#  67: 'do',
#  68: 'other',
#  69: 'been',
#  70: 'over',
#  71: 'these',
#  72: 'will',
#  73: 'though',
#  74: 'only',
#  75: 'its',
#  76: 'down',
#  77: 'such',
#  78: 'who',
#  79: 'yet',
#  80: 'head',
#  81: 'time',
#  82: 'long',
#  83: 'boat',
#  84: 'her',
#  85: 'any',
#  86: 'captain',
#  87: 'very',
#  88: 'here',
#  89: 'still',
#  90: 'about',
#  91: 'those',
#  92: 'than',
#  93: 'before',
#  94: 'great',
#  95: 'two',
#  96: 'has',
#  97: 'said',
#  98: 'did',
#  99: 'seemed',
#  100: 'must',
#  101: 'white',
#  102: 'last',
#  103: 'most',
#  104: 'way',
#  105: 'after',
#  106: 'thou',
#  107: 'can',
#  108: 'see',
#  109: 'again',
#  110: 'stubb',
#  111: "n't",
#  112: 'queequeg',
#  113: 'little',
#  114: 'whales',
#  115: 'round',
#  116: 'how',
#  117: 'your',
#  118: 'three',
#  119: 'while',
#  120: 'men',
#  121: 'sperm',
#  122: 'say',
#  123: 'may',
#  124: 'first',
#  125: 'every',
#  126: 'well',
#  127: 'through',
#  128: 'us',
#  129: 'much',
#  130: 'could',
#  131: 'being',
#  132: 'off',
#  133: 'good',
#  134: 'same',
#  135: 'where',
#  136: 'hand',
#  137: 'side',
#  138: 'own',
#  139: 'our',
#  140: 'never',
#  141: 'himself',
#  142: 'ever',
#  143: 'look',
#  144: 'starbuck',
#  145: 'deck',
#  146: 'almost',
#  147: 'go',
#  148: 'even',
#  149: 'thing',
#  150: 'water',
#  151: 'too',
#  152: 'away',
#  153: 'might',
#  154: 'should',
#  155: 'made',
#  156: 'come',
#  157: 'day',
#  158: 'chapter',
#  159: 'pequod',
#  160: 'world',
#  161: 'life',
#  162: 'among',
#  163: 'far',
#  164: 'many',
#  165: 'fish',
#  166: 'back',
#  167: 'seen',
#  168: 'line',
#  169: 'let',
#  170: 'eyes',
#  171: 'sir',
#  172: 'nor',
#  173: 'without',
#  174: 'sort',
#  175: 'thought',
#  176: 'part',
#  177: 'night',
#  178: 'cried',
#  179: 'know',
#  180: 'oh',
#  181: 'right',
#  182: 'once',
#  183: 'god',
#  184: 'aye',
#  185: 'boats',
#  186: 'air',
#  187: 'crew',
#  188: 'whole',
#  189: 'half',
#  190: 'against',
#  191: '\n\n\n\n',
#  192: 'tell',
#  193: 'thus',
#  194: 'things',
#  195: 'thee',
#  196: 'soon',
#  197: 'take',
#  198: 'each',
#  199: 'came',
#  200: 'small',
#  201: 'whaling',
#  202: 'hands',
#  203: 'feet',
#  204: 'mast',
#  205: 'something',
#  206: 'both',
#  207: 'full',
#  208: 'between',
#  209: 'till',
#  210: 'under',
#  211: 'think',
#  212: 'just',
#  213: 'place',
#  214: 'why',
#  215: 'towards',
#  216: 'she',
#  217: 'thy',
#  218: 'nothing',
#  219: 'found',
#  220: 'called',
#  221: 'times',
#  222: 'another',
#  223: 'along',
#  224: 'poor',
#  225: 'make',
#  226: 'body',
#  227: 'flask',
#  228: 'high',
#  229: 'heard',
#  230: 'sight',
#  231: 'moment',
#  232: "'ll",
#  233: 'saw',
#  234: 'stand',
#  235: 'end',
#  236: 'sun',
#  237: 'strange',
#  238: 'does',
#  239: 'hold',
#  240: 'sail',
#  241: 'new',
#  242: 'went',
#  243: 'voyage',
#  244: 'get',
#  245: 'face',
#  246: 'however',
#  247: 'years',
#  248: 'few',
#  249: 'black',
#  250: 'because',
#  251: 'dead',
#  252: 'shall',
#  253: 'stood',
#  254: 'going',
#  255: 'indeed',
#  256: 'am',
#  257: 'perhaps',
#  258: 'nantucket',
#  259: 'certain',
#  260: 'also',
#  261: 'whether',
#  262: 'death',
#  263: 'iron',
#  264: 'leg',
#  265: 'eye',
#  266: 'arm',
#  267: 'seems',
#  268: 'heart',
#  269: 'oil',
#  270: 'ships',
#  271: 'heads',
#  272: 'true',
#  273: 'wild',
#  274: 'seas',
#  275: 'matter',
#  276: 'whose',
#  277: 'sometimes',
#  278: 'cabin',
#  279: 'leviathan',
#  280: 'hard',
#  281: 'itself',
#  282: 'seem',
#  283: 'moby',
#  284: 'soul',
#  285: 'give',
#  286: 'jonah',
#  287: 'standing',
#  288: 'dick',
#  289: 'sailor',
#  290: 'days',
#  291: 'always',
#  292: 'young',
#  293: 'present',
#  294: 'ere',
#  295: 'harpooneer',
#  296: 'mind',
#  297: 'light',
#  298: 'land',
#  299: 'within',
#  300: 'enough',
#  301: 'harpoon',
#  302: 'bed',
#  303: 'tail',
#  304: 'instant',
#  305: 'known',
#  306: 'mate',
#  307: 'bildad',
#  308: 'lay',
#  309: 'large',
#  310: 'beneath',
#  311: 'length',
#  312: 'set',
#  313: 'morning',
#  314: 'done',
#  315: 'least',
#  316: 'peleg',
#  317: 'put',
#  318: 'fire',
#  319: 'pip',
#  320: 'yes',
#  321: 'open',
#  322: 'four',
#  323: 'word',
#  324: 'often',
#  325: 'ocean',
#  326: 'board',
#  327: 'whalemen',
#  328: 'case',
#  329: 'living',
#  330: 'looking',
#  331: 'point',
#  332: 'general',
#  333: 'rather',
#  334: 'waters',
#  335: 'business',
#  336: 'vast',
#  337: 'left',
#  338: 'deep',
#  339: 'name',
#  340: 'wind',
#  341: 'keep',
#  342: 'top',
#  343: 'myself',
#  344: 'turned',
#  345: 'therefore',
#  346: 'best',
#  347: 'having',
#  348: 'since',
#  349: 'reason',
#  350: 'looked',
#  351: 'near',
#  352: 'work',
#  353: 'better',
#  354: 'boy',
#  355: 'lord',
#  356: 'fishery',
#  357: 'fast',
#  358: 'lower',
#  359: 'order',
#  360: 'further',
#  361: 'hear',
#  362: 'together',
#  363: 'turn',
#  364: 'live',
#  365: 'blood',
#  366: 'second',
#  367: 'short',
#  368: 'fine',
#  369: 'book',
#  370: 'mr.',
#  371: 'spout',
#  372: 'themselves',
#  373: 'chase',
#  374: 'watch',
#  375: 'broad',
#  376: 'rope',
#  377: 'dark',
#  378: 'room',
#  379: 'above',
#  380: 'king',
#  381: 'mouth',
#  382: 'indian',
#  383: 'feel',
#  384: 'ivory',
#  385: 'jaw',
#  386: 'next',
#  387: 'aloft',
#  388: 'savage',
#  389: 'harpooneers',
#  390: 'entire',
#  391: 'peculiar',
#  392: 'tashtego',
#  393: 'find',
#  394: 'gone',
#  395: 'goes',
#  396: 'craft',
#  397: 'bottom',
#  398: 'mark',
#  399: 'home',
#  400: 'curious',
#  401: 'ground',
#  402: 'call',
#  403: 'try',
#  404: 'grand',
#  405: 'fellow',
#  406: 'devil',
#  407: 'began',
#  408: 'comes',
#  409: 'coming',
#  410: 'sailors',
#  411: 'run',
#  412: 'cut',
#  413: 'turning',
#  414: 'close',
#  415: 'green',
#  416: 'less',
#  417: 'forth',
#  418: 'rest',
#  419: 'slowly',
#  420: 'main',
#  421: 'vessel',
#  422: 'stern',
#  423: 'forward',
#  424: 'coffin',
#  425: 'thousand',
#  426: 'taking',
#  427: 'speak',
#  428: 'heaven',
#  429: 'nevertheless',
#  430: 'broken',
#  431: 'bone',
#  432: 'sharks',
#  433: 'suddenly',
#  434: 'story',
#  435: 'cook',
#  436: 'took',
#  437: 'hundred',
#  438: 'common',
#  439: 'bows',
#  440: 'taken',
#  441: 'below',
#  442: 'particular',
#  443: 'besides',
#  444: 'wide',
#  445: 'teeth',
#  446: 'used',
#  447: 'stranger',
#  448: 'carpenter',
#  449: 'waves',
#  450: 'quarter',
#  451: 'behind',
#  452: 'struck',
#  453: 'kept',
#  454: 'ten',
#  455: 'sleep',
#  456: 'else',
#  457: 'monster',
#  458: 'voice',
#  459: 'fact',
#  460: 'got',
#  461: 'running',
#  462: 'several',
#  463: 'lost',
#  464: 'bones',
#  465: 'english',
#  466: 'pull',
#  467: 'people',
#  468: 'straight',
#  469: 'blue',
#  470: 'making',
#  471: 'view',
#  472: 'sure',
#  473: 'mighty',
#  474: 'chance',
#  475: 'whaleman',
#  476: 'whatever',
#  477: 'especially',
#  478: 'nigh',
#  479: 'house',
#  480: 'door',
#  481: 'lance',
#  482: 'sat',
#  483: 'touching',
#  484: 'means',
#  485: 'knew',
#  486: 'somehow',
#  487: 'anything',
#  488: 'rolled',
#  489: 'queer',
#  490: 'says',
#  491: 'seamen',
#  492: 'five',
#  493: 'hole',
#  494: 'sudden',
#  495: 'form',
#  496: 'bow',
#  497: 'noble',
#  498: 'hours',
#  499: 'told',
#  500: 'passed',
#  501: 'mine',
#  502: 'caught',
#  503: 'creature',
#  504: 'earth',
#  505: 'wondrous',
#  506: 'surface',
#  507: 'quite',
#  508: 'parts',
#  509: 'whom',
#  510: 'felt',
#  511: 'course',
#  512: 'sound',
#  513: 'brow',
#  514: 'sails',
#  515: 'mortal',
#  516: 'cape',
#  517: 'red',
#  518: 'hour',
#  519: 'sharp',
#  520: 'alone',
#  521: 'ready',
#  522: "'em",
#  523: 'saying',
#  524: 'clear',
#  525: 'concerning',
#  526: 'hat',
#  527: 'mates',
#  528: 'calm',
#  529: 'nature',
#  530: 'steelkilt',
#  531: 'single',
#  532: 'easy',
#  533: 'purpose',
#  534: 'wake',
#  535: 'coast',
#  536: 'wo',
#  537: 'pipe',
#  538: 'mere',
#  539: 'makes',
#  540: 'art',
#  541: 'gold',
#  542: 'oars',
#  543: 'mean',
#  544: 'others',
#  545: 'various',
#  546: 'sailed',
#  547: 'low',
#  548: 'mass',
#  549: 'plain',
#  550: 'cry',
#  551: 'darted',
#  552: 'gave',
#  553: 'plainly',
#  554: 'power',
#  555: 'object',
#  556: 'distance',
#  557: 'de',
#  558: 'chief',
#  559: 'forecastle',
#  560: 'bear',
#  561: 'quick',
#  562: 'famous',
#  563: 'suppose',
#  564: 'lines',
#  565: 'human',
#  566: 'table',
#  567: 'forehead',
#  568: 'help',
#  569: 'held',
#  570: 'skin',
#  571: 'leaving',
#  572: 'seeing',
#  573: 'flukes',
#  574: 'heavy',
#  575: 'arms',
#  576: 'cutting',
#  577: 'aspect',
#  578: 'daggoo',
#  579: 'gentlemen',
#  580: 'fixed',
#  581: 'bulwarks',
#  582: 'legs',
#  583: 'either',
#  584: 'wonder',
#  585: 'brought',
#  586: 'middle',
#  587: 'sign',
#  588: 'ha',
#  589: 'manner',
#  590: 'unknown',
#  591: 'placed',
#  592: 'truth',
#  593: 'sky',
#  594: 'born',
#  595: 'use',
#  596: 'given',
#  597: 'natural',
#  598: 'shot',
#  599: 'previous',
#  600: 'around',
#  601: 'holding',
#  602: 'weather',
#  603: 'wood',
#  604: 'fell',
#  605: 'turns',
#  606: 'loose',
#  607: 'strong',
#  608: 'town',
#  609: 'boys',
#  610: 'spring',
#  611: 'fair',
#  612: 'none',
#  613: 'thoughts',
#  614: 'rolling',
#  615: 'hope',
#  616: 'remained',
#  617: 'twenty',
#  618: 'skeleton',
#  619: 'start',
#  620: 'brain',
#  621: 'sailing',
#  622: 'greenland',
#  623: 'fin',
#  624: 'blubber',
#  625: 'nearly',
#  626: 'rigging',
#  627: 'american',
#  628: 'creatures',
#  629: 'idea',
#  630: 'stop',
#  631: 'foot',
#  632: 'landlord',
#  633: 'want',
#  634: 'company',
#  635: 'mad',
#  636: 'completely',
#  637: 'hardly',
#  638: 'rose',
#  639: 'account',
#  640: 'island',
#  641: 'pacific',
#  642: 'already',
#  643: 'darkness',
#  644: 'visible',
#  645: 'kill',
#  646: 'ashore',
#  647: 'hammock',
#  648: 'fear',
#  649: 'drawing',
#  650: 'during',
#  651: 'third',
#  652: 'show',
#  653: 'steel',
#  654: 'proper',
#  655: 'hence',
#  656: 'nose',
#  657: 'intervals',
#  658: 'hull',
#  659: 'ago',
#  660: 'considering',
#  661: 'bulk',
#  662: 'cold',
#  663: 'harpoons',
#  664: 'jet',
#  665: 'tossed',
#  666: 'passage',
#  667: 'fifty',
#  668: 'forty',
#  669: 'planks',
#  670: 'knife',
#  671: "'ve",
#  672: 'ca',
#  673: 'soft',
#  674: 'doubt',
#  675: 'fresh',
#  676: 'ho',
#  677: 'substance',
#  678: 'cast',
#  679: 'helm',
#  680: 'across',
#  681: 'woe',
#  682: 'aft',
#  683: 'except',
#  684: "d'ye",
#  685: 'instances',
#  686: 'rising',
#  687: 'upper',
#  688: 'possibly',
#  689: 'smoke',
#  690: 'vain',
#  691: 'act',
#  692: 'really',
#  693: 'snow',
#  694: 'horn',
#  695: 'flying',
#  696: 'hung',
#  697: 'storm',
#  698: 'carried',
#  699: 'pass',
#  700: 'strike',
#  701: 'o',
#  702: 'die',
#  703: 'free',
#  704: 'suspended',
#  705: 'shark',
#  706: 'hammer',
#  707: 'species',
#  708: 'hoisted',
#  709: 'unless',
#  710: 'astern',
#  711: 'battle',
#  712: 'nay',
#  713: 'words',
#  714: 'works',
#  715: 'final',
#  716: 'stands',
#  717: 'mariners',
#  718: 'generally',
#  719: 'six',
#  720: 'certainly',
#  721: 'possible',
#  722: 'lamp',
#  723: 'touch',
#  724: 'question',
#  725: 'killed',
#  726: 'sideways',
#  727: 'pointed',
#  728: 'strangely',
#  729: 'leeward',
#  730: 'pole',
#  731: 'leaning',
#  732: 'miles',
#  733: 'knows',
#  734: 'mild',
#  735: 'huge',
#  736: 'late',
#  737: 'meanwhile',
#  738: 'i.',
#  739: 'gods',
#  740: 'supper',
#  741: 'shipmates',
#  742: 'become',
#  743: 'person',
#  744: 'thinking',
#  745: 'pretty',
#  746: 'entirely',
#  747: 'aside',
#  748: 'glance',
#  749: 'thunder',
#  750: 'swimming',
#  751: 'hunters',
#  752: 'oar',
#  753: 'seated',
#  754: 'bound',
#  755: 'south',
#  756: 'bit',
#  757: 'coat',
#  758: 'royal',
#  759: 'believe',
#  760: 'started',
#  761: 'ice',
#  762: 'thick',
#  763: 'wooden',
#  764: 'sides',
#  765: 'altogether',
#  766: 'hump',
#  767: 'feeling',
#  768: 'eyeing',
#  769: 'lightning',
#  770: 'giving',
#  771: 'pilot',
#  772: 'looks',
#  773: 'fishermen',
#  774: 'overboard',
#  775: 'scene',
#  776: 'read',
#  777: 'command',
#  778: 'ancient',
#  779: 'dropped',
#  780: 'wholly',
#  781: 'hast',
#  782: 'steady',
#  783: 'alongside',
#  784: 'play',
#  785: 'whiteness',
#  786: 'fedallah',
#  787: 'precisely',
#  788: 'cruising',
#  789: 'degree',
#  790: 'silent',
#  791: 'yourself',
#  792: 'considerable',
#  793: 'horse',
#  794: 'finally',
#  795: 'drawn',
#  796: 'circumstances',
#  797: 'port',
#  798: 'followed',
#  799: 'ears',
#  800: 'lie',
#  801: 'midnight',
#  802: 'hair',
#  803: 'fancy',
#  804: 'jaws',
#  805: 'somewhat',
#  806: 'chest',
#  807: 'getting',
#  808: "'m",
#  809: 'otherwise',
#  810: 'thirty',
#  811: 'war',
#  812: 'circumstance',
#  813: 'alive',
#  814: 'gale',
#  815: 'sweet',
#  816: 'wise',
#  817: 'hearts',
#  818: 'father',
#  819: 'state',
#  820: 'friend',
#  821: 'bodily',
#  822: 'according',
#  823: 'ahead',
#  824: 'blow',
#  825: 'parsee',
#  826: 'watery',
#  827: 'drop',
#  828: 'kind',
#  829: 'afterwards',
#  830: 'talk',
#  831: 'masts',
#  832: 'enormous',
#  833: 'cases',
#  834: 'number',
#  835: 'received',
#  836: 'interval',
#  837: 'duty',
#  838: 'similar',
#  839: 'skull',
#  840: 'takes',
#  841: 'wife',
#  842: 'year',
#  843: 'headed',
#  844: 'complete',
#  845: 'keel',
#  846: 'bearing',
#  847: 'hinted',
#  848: 'spread',
#  849: 'vessels',
#  850: 'eight',
#  851: 'yards',
#  852: 'sword',
#  853: 'honour',
#  854: 'orders',
#  855: 'captains',
#  856: 'fore',
#  857: 'answer',
#  858: 'exactly',
#  859: 'following',
#  860: 'became',
#  861: 'beyond',
#  862: 'tall',
#  863: 'fiery',
#  864: 'floating',
#  865: 'dart',
#  866: 'wall',
#  867: 'swift',
#  868: 'added',
#  869: 'seldom',
#  870: 'owing',
#  871: 'self',
#  872: 'carry',
#  873: 'instead',
#  874: 'beat',
#  875: 'front',
#  876: 'learned',
#  877: 'escape',
#  878: 'circle',
#  879: 'strength',
#  880: 'thyself',
#  881: 'secret',
#  882: 'remains',
#  883: 'hunt',
#  884: 'level',
#  885: 'dutch',
#  886: 'pulling',
#  887: 'country',
#  888: 'ai',
#  889: 'perils',
#  890: 'love',
#  891: 'bright',
#  892: 'negro',
#  893: 'spot',
#  894: 'warm',
#  895: 'lances',
#  896: 'flew',
#  897: 'higher',
#  898: 'break',
#  899: 'somewhere',
#  900: 'thrown',
#  901: 'yellow',
#  902: 'hot',
#  903: 'passing',
#  904: 'real',
#  905: 'hidden',
#  906: 'meantime',
#  907: 'pagan',
#  908: 'ran',
#  909: 'instantly',
#  910: 'commanded',
#  911: 'flesh',
#  912: 'burst',
#  913: 'regarded',
#  914: 'regular',
#  915: 'speaking',
#  916: 'consider',
#  917: 'different',
#  918: 'remain',
#  919: 'scuttle',
#  920: 'gazing',
#  921: 'st.',
#  922: 'lakeman',
#  923: 'shore',
#  924: 'east',
#  925: 'grow',
#  926: 'formed',
#  927: 'sitting',
#  928: 'wonderful',
#  929: 'centre',
#  930: 'filled',
#  931: 'sleeping',
#  932: 'pursuit',
#  933: 'cause',
#  934: 'striking',
#  935: 'likewise',
#  936: 'jacket',
#  937: 'terrible',
#  938: 'drew',
#  939: 'deadly',
#  940: 'hint',
#  941: 'step',
#  942: 'descried',
#  943: 'lad',
#  944: 'master',
#  945: 'souls',
#  946: 'post',
#  947: 'nantucketer',
#  948: 'seventy',
#  949: 'sink',
#  950: 'dashed',
#  951: 'log',
#  952: 'windlass',
#  953: 'advance',
#  954: 'golden',
#  955: 'tis',
#  956: 'radney',
#  957: 'rear',
#  958: 'distant',
#  959: 'winds',
#  960: 'decks',
#  961: 'jolly',
#  962: 'bag',
#  963: 'original',
#  964: 'worse',
#  965: 'lives',
#  966: 'repeated',
#  967: 'truly',
#  968: "'d",
#  969: 'minutes',
#  970: 'spare',
#  971: 'stove',
#  972: 'anchor',
#  973: 'aboard',
#  974: 'empty',
#  975: 'quickly',
#  976: 'lofty',
#  977: 'age',
#  978: 'terrors',
#  979: 'laid',
#  980: 'base',
#  981: 'french',
#  982: 'invested',
#  983: 'windward',
#  984: 'evinced',
#  985: 'attached',
#  986: 'terror',
#  987: 'beheld',
#  988: 'gunwale',
#  989: 'blacksmith',
#  990: 'virtue',
#  991: 'hollow',
#  992: 'lies',
#  993: 'tree',
#  994: 'holy',
#  995: 'separate',
#  996: 'needs',
#  997: 'thinks',
#  998: 'ah',
#  999: 'swung',
#  1000: 'inches',
#  ...}

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 158 : chapter
# 9443 : 1
# 17526 : loomings
# 402 : call
# 42 : me
# 1043 : ishmael
# 43 : some
# 247 : years
# 659 : ago
# 140 : never
# 296 : mind
# 116 : how
# 82 : long
# 787 : precisely
# 347 : having
# 113 : little
# 36 : or
# 50 : no
# 1788 : money
# 6 : in
# 49 : my
# 3028 : purse
# 3 : and
# 218 : nothing
# 442 : particular
# 5 : to

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('chapter', 4447),
#              ('1', 28),
#              ('loomings', 3),
#              ('call', 1382),
#              ('me', 16095),
#              ('ishmael', 500),
#              ('some', 15789),
#              ('years', 2400),
#              ('ago', 815),
#              ('never', 5262),
#              ('mind', 2039),
#              ('how', 6330),
#              ('long', 8567),
#              ('precisely', 690),
#              ('having', 1679),
#              ('little', 6412),
#              ('or', 17879),
#              ('no', 14916),
#              ('money', 305),
#              ('in', 105799),
#              ('my', 15231),
#              ('purse', 178),
#              ('and', 164029),
#              ('nothing', 2936),
#              ('particular', 1273),
#              ('to', 117832),
#              ('interest', 442),
#              ('on', 26910),
#              ('shore', 572),
#              ('i', 53430),
#              ('thought', 3874),
#              ('would', 11232),
#              ('sail', 2522),
#              ('about', 7982),
#              ('a', 119756),
#              ('see', 6734),
#              ('the', 367474),
#              ('watery', 650),
#              ('part', 3874),
#              ('of', 168116),
#              ('world', 4420),
#              ('it', 64056),
#              ('is', 43758),
#              ('way', 6942),
#              ('have', 19604),
#              ('driving', 234),
#              ('off', 5642),
#              ('spleen', 26),
#              ('regulating', 26),
#              ('circulation', 26),
#              ('whenever', 390),
#              ('find', 1404),
#              ('myself', 1716),
#              ('growing', 234),
#              ('grim', 286),
#              ('mouth', 1456),
#              ('damp', 234),
#              ('drizzly', 26),
#              ('november', 52),
#              ('soul', 2132),
#              ('involuntarily', 312),
#              ('pausing', 260),
#              ('before', 7644),
#              ('coffin', 1300),
#              ('warehouses', 52),
#              ('bringing', 260),
#              ('up', 13151),
#              ('rear', 546),
#              ('every', 5850),
#              ('funeral', 130),
#              ('meet', 468),
#              ('especially', 1144),
#              ('hypos', 26),
#              ('get', 2470),
#              ('such', 9542),
#              ('an', 15262),
#              ('upper', 780),
#              ('hand', 5434),
#              ('that', 78532),
#              ('requires', 156),
#              ('strong', 884),
#              ('moral', 78),
#              ('principle', 234),
#              ('prevent', 130),
#              ('from', 27872),
#              ('deliberately', 208),
#              ('stepping', 182),
#              ('into', 13442),
#              ('street', 312),
#              ('methodically', 78),
#              ('knocking', 182),
#              ('people', 1170),
#              ("'s", 44772),
#              ('hats', 104),
#              ('then', 16172),
#              ('account', 832),
#              ('high', 2756),
#              ('time', 8632),
#              ('sea', 11310),
#              ('as', 44564),
#              ('soon', 3328),
#              ('can', 6838),
#              ('this', 35620),
#              ('substitute', 78),
#              ('for', 41184),
#              ('pistol', 156),
#              ('ball', 286),
#              ('with', 43966),
#              ('philosophical', 26),
#              ('flourish', 78),
#              ('cato', 26),
#              ('throws', 78),
#              ('himself', 5252),
#              ('upon', 14586),
#              ('his', 64792),
#              ('sword', 624),
#              ('quietly', 494),
#              ('take', 3302),
#              ('ship', 13182),
#              ('there', 21580),
#              ('surprising', 182),
#              ('if', 12298),
#              ('they', 16848),
#              ('but', 46254),
#              ('knew', 1118),
#              ('almost', 5018),
#              ('all', 39052),
#              ('men', 6240),
#              ('their', 15704),
#              ('degree', 676),
#              ('other', 10608),
#              ('cherish', 234),
#              ('very', 8268),
#              ('nearly', 858),
#              ('same', 5460),
#              ('feelings', 156),
#              ('towards', 2938),
#              ('ocean', 1846),
#              ('now', 20124),
#              ('your', 6292),
#              ('insular', 104),
#              ('city', 364),
#              ('manhattoes', 26),
#              ('belted', 78),
#              ('round', 6344),
#              ('by', 30524),
#              ('wharves', 130),
#              ('indian', 1456),
#              ('isles', 442),
#              ('coral', 182),
#              ('reefs', 26),
#              ('commerce', 156),
#              ('surrounds', 52),
#              ('her', 8466),
#              ('surf', 130),
#              ('right', 3770),
#              ('left', 1742),
#              ('streets', 364),
#              ('you', 22906),
#              ('waterward', 52),
#              ('its', 9646),
#              ('extreme', 338),
#              ('downtown', 26),
#              ('battery', 78),
#              ('where', 5460),
#              ('noble', 1092),
#              ('mole', 78),
#              ('washed', 104),
#              ('waves', 1222),
#              ('cooled', 52),
#              ('breezes', 104),
#              ('which', 16224),
#              ('few', 2392),
#              ('hours', 1092),
#              ('previous', 910),
#              ('were', 17550),
#              ('out', 13572),
#              ('sight', 2704),
#              ('land', 2002),
#              ('look', 5200),
#              ('at', 33846),
#              ('crowds', 130),
#              ('water', 4706),
#              ('gazers', 26),
#              ('circumambulate', 26),
#              ('dreamy', 104),
#              ('sabbath', 104),
#              ('afternoon', 234),
#              ('go', 4940),
#              ('corlears', 26),
#              ('hook', 468),
#              ('coenties', 26),
#              ('slip', 104),
#              ('thence', 182),
#              ('whitehall', 26),
#              ('northward', 78),
#              ('what', 15574),
#              ('do', 10738),
#              ('see?--posted', 26),
#              ('like', 16562),
#              ('silent', 676),
#              ('sentinels', 26),
#              ('around', 910),
#              ('town', 884),
#              ('stand', 2600),
#              ('thousands', 416),
#              ('mortal', 1040),
#              ('fixed', 936),
#              ('reveries', 156),
#              ('leaning', 728),
#              ('against', 3458),
#              ('spiles', 26),
#              ('seated', 702),
#              ('pier', 26),
#              ('heads', 2184),
#              ('looking', 1820),
#              ('over', 10478),
#              ('bulwarks', 936),
#              ('ships', 2210),
#              ('china', 234),
#              ('aloft', 1430),
#              ('rigging', 858),
#              ('striving', 260),
#              ('still', 8086),
#              ('better', 1612),
#              ('seaward', 52),
#              ('peep', 208),
#              ('these', 10166),
#              ('are', 15236),
#              ('landsmen', 260),
#              ('week', 130),
#              ('days', 2080),
#              ('pent', 52),
#              ('lath', 26),
#              ('plaster', 78),
#              ('tied', 312),
#              ('counters', 26),
#              ('nailed', 286),
#              ('benches', 52),
#              ('clinched', 78),
#              ('desks', 26),
#              ('green', 1326),
#              ('fields', 208),
#              ('gone', 1404),
#              ('here', 8190),
#              ('come', 4524),
#              ('more', 13000),
#              ('pacing', 286),
#              ('straight', 1170),
#              ('seemingly', 234),
#              ('bound', 702),
#              ('dive', 208),
#              ('strange', 2548),
#              ('will', 9906),
#              ('content', 468),
#              ('them', 11986),
#              ('extremest', 52),
#              ('limit', 130),
#              ('loitering', 26),
#              ('under', 3068),
#              ('shady', 26),
#              ('lee', 468),
#              ('yonder', 468),
#              ('not', 31304),
#              ('suffice', 52),
#              ('must', 7306),
#              ('just', 3042),
#              ('nigh', 1144),
#              ('possibly', 780),
#              ('without', 3978),
#              ('falling', 312),
#              ('miles', 728),
#              ('leagues', 260),
#              ('inlanders', 26),
#              ('lanes', 26),
#              ('alleys', 26),
#              ('avenues', 78),
#              ('north', 364),
#              ('east', 572),
#              ('south', 702),
#              ('west', 390),
#              ('yet', 8944),
#              ('unite', 156),
#              ('tell', 3432),
#              ('does', 2548),
#              ('magnetic', 182),
#              ('virtue', 520),
#              ('needles', 286),
#              ('compasses', 260),
#              ('those', 7878),
#              ('attract', 26),
#              ('thither', 260),
#              ('once', 3770),
#              ('say', 6136),
#              ('country', 598),
#              ('lakes', 78),
#              ('any', 8346),
#              ('path', 234),
#              ('please', 312),
#              ('ten', 1196),
#              ('one', 23556),
#              ('carries', 416),
#              ('down', 9620),
#              ('dale', 26),
#              ('leaves', 494),
#              ('pool', 130),
#              ('stream', 260),
#              ('magic', 234),
#              ('let', 4030),
#              ('most', 7124),
#              ('absent', 260),
#              ('minded', 156),
#              ('be', 26806),
#              ('plunged', 234),
#              ('deepest', 156),
#              ('man', 13520),
#              ('legs', 936),
#              ('set', 1924),
#              ('feet', 3224),
#              ('going', 2314),
#              ('he', 48334),
#              ('infallibly', 286),
#              ('lead', 442),
#              ('region', 104),
#              ('should', 4628),
#              ('ever', 5226),
#              ('athirst', 78),
#              ('great', 7592),
#              ('american', 858),
#              ('desert', 208),
#              ('try', 1378),
#              ('experiment', 104),
#              ('caravan', 52),
#              ('happen', 208),
#              ('supplied', 260),
#              ('metaphysical', 52),
#              ('professor', 104),
#              ('yes', 1872),
#              ('knows', 728),
#              ('meditation', 104),
#              ('wedded', 130),
#              ('artist', 104),
#              ('desires', 104),
#              ('paint', 130),
#              ('dreamiest', 26),
#              ('shadiest', 26),
#              ('quietest', 26),
#              ('enchanting', 26),
#              ('bit', 702),
#              ('romantic', 182),
#              ('landscape', 78),
#              ('valley', 156),
#              ('saco', 26),
#              ('chief', 962),
#              ('element', 260),
#              ('employs', 52),
#              ('trees', 364),
#              ('each', 3302),
#              ('hollow', 520),
#              ('trunk', 442),
#              ('hermit', 78),
#              ('crucifix', 26),
#              ('within', 1976),
#              ('sleeps', 130),
#              ('meadow', 156),
#              ('sleep', 1196),
#              ('cattle', 156),
#              ('cottage', 52),
#              ('goes', 1404),
#              ('sleepy', 208),
#              ('smoke', 780),
#              ('deep', 1742),
#              ('distant', 546),
#              ('woodlands', 52),
#              ('winds', 546),
#              ('mazy', 26),
#              ('reaching', 312),
#              ('overlapping', 52),
#              ('spurs', 52),
#              ('mountains', 338),
#              ('bathed', 52),
#              ('hill', 416),
#              ('side', 5330),
#              ('blue', 1170),
#              ('though', 9750),
#              ('picture', 494),
#              ('lies', 520),
#              ('thus', 3432),
#              ('tranced', 78),
#              ('pine', 286),
#              ('tree', 520),
#              ('shakes', 104),
#              ('sighs', 52),
#              ('shepherd', 52),
#              ('head', 8710),
#              ('vain', 780),
#              ('unless', 754),
#              ('eye', 2236),
#              ('him', 27248),
#              ('visit', 260),
#              ('prairies', 156),
#              ('june', 52),
#              ('when', 15496),
#              ('scores', 104),
#              ('wade', 78),
#              ('knee', 208),
#              ('among', 4238),
#              ('tiger', 286),
#              ('lilies', 52),
#              ('charm', 182),
#              ('wanting?--water', 26),
#              ('drop', 650),
#              ('niagara', 52),
#              ('cataract', 52),
#              ('sand', 286),
#              ('travel', 156),
#              ('thousand', 1300),
#              ('why', 2990),
#              ('did', 7332),
#              ('poor', 2834),
#              ('poet', 52),
#              ('tennessee', 26),
#              ('suddenly', 1274),
#              ('receiving', 338),
#              ('two', 7592),
#              ('handfuls', 104),
#              ('silver', 312),
#              ('deliberate', 130),
#              ('whether', 2262),
#              ('buy', 78),
#              ('coat', 702),
#              ('sadly', 312),
#              ('needed', 182),
#              ('invest', 156),
#              ('pedestrian', 52),
#              ('trip', 104),
#              ('rockaway', 26),
#              ('beach', 468),
#              ('robust', 78),
#              ('healthy', 130),
#              ('boy', 1612),
#              ('crazy', 338),
#              ('first', 6006),
#              ('voyage', 2496),
#              ('passenger', 156),
#              ('yourself', 676),
#              ('feel', 1456),
#              ('mystical', 234),
#              ('vibration', 130),
#              ('told', 1092),
#              ('old', 11570),
#              ('persians', 26),
#              ('hold', 2548),
#              ('holy', 520),
#              ('greeks', 52),
#              ('give', 2132),
#              ('separate', 520),
#              ('deity', 104),
#              ('own', 5278),
#              ('brother', 286),
#              ('jove', 234),
#              ('surely', 182),
#              ('meaning', 416),
#              ('deeper', 494),
#              ('story', 1274),
#              ('narcissus', 26),
#              ('who', 9282),
#              ('because', 2366),
#              ('could', 5694),
#              ('grasp', 130),
#              ('tormenting', 52),
#              ('mild', 728),
#              ('image', 286),
#              ('saw', 2626),
#              ('fountain', 234),
#              ('was', 42319),
#              ('drowned', 312),
#              ('we', 11570),
#              ('ourselves', 390),
#              ('rivers', 78),
#              ('oceans', 416),
#              ('ungraspable', 26),
#              ('phantom', 364),
#              ('life', 4368),
#              ('key', 312),
#              ('am', 2288),
#              ('habit', 78),
#              ('begin', 312),
#              ('grow', 572),
#              ('hazy', 26),
#              ('eyes', 4030),
#              ('conscious', 208),
#              ('lungs', 390),
#              ('mean', 988),
#              ('inferred', 104),
#              ('needs', 520),
#              ('rag', 52),
#              ('something', 3172),
#              ('besides', 1248),
#              ('passengers', 130),
#              ('sick', 260),
#              ('quarrelsome', 26),
#              ("don't", 208),
#              ('nights', 286),
#              ('enjoy', 130),
#              ('themselves', 1508),
#              ('much', 5720),
#              ('general', 1794),
#              ('thing;--no', 26),
#              ('nor', 4004),
#              ('salt', 312),
#              ('commodore', 234),
#              ('captain', 8346),
#              ('cook', 1274),
#              ('abandon', 78),
#              ('glory', 468),
#              ('distinction', 104),
#              ('offices', 26),
#              ('abominate', 26),
#              ('honourable', 182),
#              ('respectable', 78),
#              ('toils', 26),
#              ('trials', 26),
#              ('tribulations', 52),
#              ('kind', 650),
#              ('whatsoever', 104),
#              ('quite', 1066),
#              ('care', 364),
#              ('taking', 1300),
#              ('barques', 26),
#              ('brigs', 78),
#              ('schooners', 26),
#              ('cook,--though', 26),
#              ('confess', 208),
#              ('considerable', 676),
#              ('being', 5668),
#              ('sort', 3926),
#              ('officer', 390),
#              ('board', 1846),
#              ('somehow', 1118),
#              ('fancied', 208),
#              ('broiling', 26),
#              ('fowls;--though', 26),
#              ('broiled', 78),
#              ('judiciously', 52),
#              ('buttered', 26),
#              ('judgmatically', 26),
#              ('salted', 156),
#              ('peppered', 26),
#              ('speak', 1300),
#              ('respectfully', 104),
#              ('reverentially', 26),
#              ('fowl', 260),
#              ('than', 7800),
#              ('idolatrous', 26),
#              ('dotings', 26),
#              ('egyptians', 104),
#              ('ibis', 26),
#              ('roasted', 26),
#              ('river', 182),
#              ('horse', 676),
#              ('mummies', 52),
#              ('creatures', 858),
#              ('huge', 728),
#              ('bake', 26),
#              ('houses', 234),
#              ('pyramids', 78),
#              ('simple', 286),
#              ('sailor', 2106),
#              ('mast', 3198),
#              ('plumb', 26),
#              ('forecastle', 962),
#              ('royal', 702),
#              ('true', 2184),
#              ('rather', 1794),
#              ('order', 1586),
#              ('make', 2834),
#              ('jump', 442),
#              ('spar', 234),
#              ('grasshopper', 52),
#              ('may', 6084),
#              ('thing', 4810),
#              ('unpleasant', 52),
#              ('enough', 1976),
#              ('touches', 52),
#              ('sense', 364),
#              ('honour', 624),
#              ('particularly', 208),
#              ('established', 78),
#              ('family', 312),
#              ('van', 130),
#              ('rensselaers', 26),
#              ('randolphs', 26),
#              ('hardicanutes', 26),
#              ('putting', 416),
#              ('tar', 234),
#              ('pot', 260),
#              ('been', 10608),
#              ('lording', 26),
#              ('schoolmaster', 156),
#              ('making', 1170),
#              ('tallest', 26),
#              ('boys', 884),
#              ('awe', 364),
#              ('transition', 130),
#              ('keen', 416),
#              ('assure', 130),
#              ('decoction', 26),
#              ('seneca', 26),
#              ('stoics', 26),
#              ('enable', 104),
#              ('grin', 182),
#              ('bear', 962),
#              ('even', 4862),
#              ('wears', 156),
#              ('hunks', 78),
#              ('orders', 624),
#              ('broom', 78),
#              ('sweep', 338),
#              ('decks', 546),
#              ('indignity', 52),
#              ('amount', 156),
#              ('weighed', 78),
#              ('scales', 156),
#              ('new', 2522),
#              ('testament', 26),
#              ('think', 3068),
#              ('archangel', 208),
#              ('gabriel', 494),
#              ('thinks', 520),
#              ('anything', 1118),
#              ('less', 1326),
#              ('promptly', 26),
#              ('obey', 182),
#              ('instance', 468),
#              ('ai', 598),
#              ("n't", 6578),
#              ('slave', 286),
#              ('well', 5850),
#              ('however', 2418),
#              ('captains', 624),
#              ('thump', 130),
#              ('punch', 156),
#              ('satisfaction', 104),
#              ('knowing', 416),
#              ('everybody', 182),
#              ('else', 1196),
#              ('served', 260),
#              ('either', 936),
#              ('physical', 104),
#              ('point', 1820),
#              ('view', 1170),
#              ('so', 27274),
#              ('universal', 208),
#              ('passed', 1092),
#              ('hands', 3250),
#              ('rub', 26),
#              ('shoulder', 286),
#              ('blades', 208),
#              ('again', 6682),
#              ('always', 2080),
#              ('paying', 78),
#              ('trouble', 234),
#              ('whereas', 442),
#              ('pay', 468),
#              ('single', 1014),
#              ('penny', 104),
#              ('heard', 2730),
#              ('contrary', 312),
#              ('difference', 468),
#              ('between', 3120),
#              ('paid', 182),
#              ('act', 780),
#              ('perhaps', 2288),
#              ('uncomfortable', 78),
#              ('infliction', 26),
#              ('orchard', 52),
#              ('thieves', 52),
#              ('entailed', 52),
#              ('us', 5772),
#              ('paid,--what', 26),
#              ('compare', 130),
#              ('urbane', 26),
#              ('activity', 234),
#              ('receives', 78),
#              ('really', 780),
#              ('marvellous', 390),
#              ('considering', 806),
#              ('earnestly', 182),
#              ('believe', 702),
#              ('root', 78),
#              ('earthly', 416),
#              ('ills', 26),
#              ('monied', 26),
#              ('enter', 260),
#              ('heaven', 1300),
#              ('ah', 520),
#              ('cheerfully', 52),
#              ('consign', 26),
#              ('perdition', 78),
#              ('finally', 676),
#              ('wholesome', 52),
#              ('exercise', 78),
#              ('pure', 234),
#              ('air', 3562),
#              ('fore', 624),
#              ('castle', 130),
#              ('deck', 5044),
#              ('far', 4238),
#              ('prevalent', 26),
#              ('astern', 754),
#              ('violate', 26),
#              ('pythagorean', 26),
#              ('maxim', 78),
#              ('quarter', 1222),
#              ('gets', 104),
#              ('atmosphere', 130),
#              ('second', 1534),
#              ('sailors', 1352),
#              ('breathes', 156),
#              ('commonalty', 26),
#              ('leaders', 52),
#              ('many', 4212),
#              ('things', 3354),
#              ('suspect', 78),
#              ('wherefore', 338),
#              ('after', 6897),
#              ('repeatedly', 78),
#              ('smelt', 78),
#              ('merchant', 468),
#              ('whaling', 3276),
#              ('invisible', 416),
#              ('police', 26),
#              ('fates', 156),
#              ('has', 7592),
#              ('constant', 130),
#              ('surveillance', 26),
#              ('secretly', 52),
#              ('dogs', 208),
#              ('influences', 182),
#              ('unaccountable', 416),
#              ('answer', 624),
#              ('doubtless', 312),
#              ('formed', 572),
#              ('grand', 1378),
#              ('programme', 26),
#              ('providence', 78),
#              ('drawn', 676),
#              ('came', 3302),
#              ('brief', 260),
#              ('interlude', 104),
#              ('solo', 26),
#              ('extensive', 78),
#              ('performances', 78),
#              ('bill', 208),
#              ('run', 1352),
#              ('contested', 26),
#              ('election', 26),
#              ('presidency', 26),
#              ('united', 234),
#              ('states', 182),
#              ('bloody', 208),
#              ('battle', 754),
#              ('affghanistan', 26),
#              ('exactly', 624),
#              ('stage', 234),
#              ('managers', 26),
#              ('put', 1898),
#              ('shabby', 78),
#              ('others', 988),
#              ('magnificent', 52),
#              ('parts', 1066),
#              ('tragedies', 52),
#              ('short', 1534),
#              ('easy', 1014),
#              ('genteel', 26),
#              ('comedies', 26),
#              ('jolly', 546),
#              ('farces', 26),
#              ('recall', 156),
#              ('circumstances', 676),
#              ('springs', 78),
#              ('motives', 104),
#              ('cunningly', 26),
#              ('presented', 494),
#              ('various', 988),
#              ('disguises', 26),
#              ('induced', 104),
#              ('performing', 78),
#              ('cajoling', 26),
#              ('delusion', 52),
#              ('choice', 130),
#              ('resulting', 52),
#              ('unbiased', 26),
#              ('freewill', 26),
#              ('discriminating', 26),
#              ('judgment', 286),
#              ('overwhelming', 26),
#              ('idea', 858),
#              ('whale', 29718),
#              ('portentous', 156),
#              ('mysterious', 260),
#              ('monster', 1196),
#              ('roused', 78),
#              ('curiosity', 234),
#              ('wild', 2184),
#              ('seas', 2184),
#              ('rolled', 1118),
#              ('island', 832),
#              ('bulk', 806),
#              ('undeliverable', 26),
#              ('nameless', 468),
#              ('perils', 598),
#              ('attending', 104),
#              ('marvels', 208),
#              ('patagonian', 104),
#              ('sights', 312),
#              ('sounds', 312),
#              ('helped', 390),
#              ('sway', 130),
#              ('wish', 338),
#              ('inducements', 52),
#              ('tormented', 364),
#              ('everlasting', 234),
#              ('itch', 26),
#              ('remote', 286),
#              ('love', 598),
#              ('forbidden', 26),
#              ('barbarous', 78),
#              ('coasts', 182),
#              ('ignoring', 26),
#              ('good', 5564),
#              ('quick', 962),
#              ('perceive', 208),
#              ('horror', 312),
#              ('social', 312),
#              ('since', 1664),
#              ('friendly', 104),
#              ('terms', 312),
#              ('inmates', 78),
#              ('place', 3016),
#              ('lodges', 26),
#              ('reason', 1664),
#              ('welcome', 156),
#              ('flood', 338),
#              ('gates', 52),
#              ('wonder', 936),
#              ('swung', 520),
#              ('open', 1872),
#              ('conceits', 104),
#              ('swayed', 130),
#              ('purpose', 1014),
#              ('floated', 442),
#              ('inmost', 52),
#              ('endless', 390),
#              ('processions', 78),
#              ('mid', 286),
#              ('hooded', 182),
#              ('snow', 780),
#              ('\n\n\n\n', 3458),
#              ('2', 26),
#              ('carpet', 208),
#              ('bag', 546),
#              ('stuffed', 104),
#              ('shirt', 234),
#              ('tucked', 78),
#              ('arm', 2236),
#              ('started', 702),
#              ('cape', 1040),
#              ('horn', 780),
#              ('pacific', 832),
#              ('quitting', 156),
#              ('manhatto', 26),
#              ('duly', 156),
#              ('arrived', 364),
#              ('bedford', 468),
#              ('saturday', 130),
#              ('night', 3874),
#              ('december', 104),
#              ('disappointed', 78),
#              ('learning', 156),
#              ('packet', 78),
#              ('nantucket', 2288),
#              ('had', 19942),
#              ('already', 832),
#              ('sailed', 988),
#              ('offer', 208),
#              ('till', 3120),
#              ('following', 624),
#              ('monday', 52),
#              ('young', 2080),
#              ('candidates', 26),
#              ('pains', 338),
#              ('penalties', 26),
#              ('stop', 858),
#              ('embark', 130),
#              ('related', 156),
#              ('doing', 390),
#              ('made', 4550),
#              ('craft', 1404),
#              ('fine', 1534),
#              ('boisterous', 78),
#              ('everything', 494),
#              ('connected', 312),
#              ('famous', 962),
#              ('amazingly', 52),
#              ('pleased', 234),
#              ('late', 728),
#              ('gradually', 260),
#              ('monopolising', 52),
#              ('business', 1768),
#              ('matter', 2184),
#              ('behind', 1222),
#              ('original', 546),
#              ('tyre', 26),
#              ('carthage;--the', 26),
#              ('dead', 2366),
#              ('stranded', 286),
#              ('aboriginal', 104),
#              ('whalemen', 1846),
#              ('red', 1040),
#              ('sally', 52),
#              ('canoes', 208),
#              ('chase', 1508),
#              ('leviathan', 2158),
#              ('too', 4654),
#              ('adventurous', 104),
#              ('sloop', 104),
#              ('forth', 1326),
#              ('partly', 364),
#              ('laden', 130),
#              ('imported', 26),
#              ('cobblestones', 26),
#              ('throw', 338),
#              ('whales', 6396),
#              ('discover', 156),
#              ('risk', 130),
#              ('harpoon', 1976),
#              ('bowsprit', 208),
#              ('day', 4524),
#              ('another', 2887),
#              ('ere', 2054),
#              ('destined', 182),
#              ('port', 676),
#              ('became', 624),
#              ('concernment', 52),
#              ('eat', 286),
#              ('meanwhile', 728),
#              ('dubious', 78),
#              ('nay', 754),
#              ('dark', 1482),
#              ('dismal', 208),
#              ('bitingly', 26),
#              ('cold', 806),
#              ('cheerless', 78),
#              ('anxious', 234),
#              ('grapnels', 52),
#              ('sounded', 208),
#              ('pocket', 312),
#              ('only', 9675),
#              ('brought', 936),
#              ('pieces', 468),
#              ('silver,--so', 26),
#              ('wherever', 156),
#              ('said', 7540),
#              ('stood', 2340),
#              ('middle', 936),
#              ('dreary', 156),
#              ('shouldering', 26),
#              ('comparing', 78),
#              ('gloom', 286),
#              ('darkness', 832),
#              ('wisdom', 130),
#              ('conclude', 208),
#              ('lodge', 78),
#              ('dear', 260),
#              ('sure', 1170),
#              ('inquire', 78),
#              ('price', 26),
#              ('halting', 104),
#              ('steps', 156),
#              ('paced', 234),
#              ('sign', 936),
#              ('crossed', 390),
#              ('harpoons"--but', 26),
#              ('looked', 1664),
#              ('expensive', 52),
#              ('further', 1586),
#              ('bright', 598),
#              ('windows', 130),
#              ('fish', 4186),
#              ('inn', 390),
#              ('fervent', 26),
#              ('rays', 156),
#              ('seemed', 7332),
#              ('melted', 130),
#              ('packed', 130),
#              ('ice', 702),
#              ('house', 1144),
#              ('everywhere', 182),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)

# %% [markdown]
# ### Convert to Numpy Matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[  158,  9443, 17526, ...,   218,   442,     5],
#        [ 9443, 17526,   402, ...,   442,     5,  1165],
#        [17526,   402,    42, ...,     5,  1165,    42],
#        ...,
#        [  240,   938,   351, ...,  1419,  1313,    74],
#        [  938,   351,  1418, ...,  1313,    74,   219],
#        [  351,  1418,     3, ...,    74,   219,   222]])

# %% [markdown]
# # Creating an LSTM based model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
def create_model(vocabulary_size, seq_len):
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150, activation='relu'))

    model.add(Dense(vocabulary_size, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
   
    model.summary()
    
    return model

# %% [markdown]
# ### Train / Test Split

# %%
from keras.utils import to_categorical

# %%
sequences
# Out:
# array([[  158,  9443, 17526, ...,   218,   442,     5],
#        [ 9443, 17526,   402, ...,   442,     5,  1165],
#        [17526,   402,    42, ...,     5,  1165,    42],
#        ...,
#        [  240,   938,   351, ...,  1419,  1313,    74],
#        [  938,   351,  1418, ...,  1313,    74,   219],
#        [  351,  1418,     3, ...,    74,   219,   222]])

# %%
# First 49 words
sequences[:,:-1]
# Out:
# array([[  158,  9443, 17526, ...,     3,   218,   442],
#        [ 9443, 17526,   402, ...,   218,   442,     5],
#        [17526,   402,    42, ...,   442,     5,  1165],
#        ...,
#        [  240,   938,   351, ...,    84,  1419,  1313],
#        [  938,   351,  1418, ...,  1419,  1313,    74],
#        [  351,  1418,     3, ...,  1313,    74,   219]])

# %%
# last Word
sequences[:,-1]
# Out:
# array([   5, 1165,   42, ...,   74,  219,  222])

# %%
X = sequences[:115000,:-1]

# %%
y = sequences[:115000,-1]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
seq_len
# Out:
# 25

# %% [markdown]
# ### Training the Model

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 25, 25)            438175
#
#  lstm (LSTM)                 (None, 25, 150)           105600
#
#  lstm_1 (LSTM)               (None, 150)               180600
#
#  dense (Dense)               (None, 150)               22650
#
#  dense_1 (Dense)             (None, 17527)             2646577
#
# =================================================================
# Total params: 3393602 (12.95 MB)
# Trainable params: 3393602 (12.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ---
#
# ----

# %%
from pickle import dump,load

# %%
# fit model
model.fit(X, y, batch_size=128, epochs=300,verbose=1)
# Out:
# Epoch 1/300
# 899/899 [==============================] - 65s 59ms/step - loss: 7.0683 - accuracy: 0.0629
# Epoch 2/300
# 899/899 [==============================] - 21s 23ms/step - loss: 6.6307 - accuracy: 0.0765
# Epoch 3/300
# 899/899 [==============================] - 23s 25ms/step - loss: 6.4304 - accuracy: 0.0844
# Epoch 4/300
# 899/899 [==============================] - 21s 23ms/step - loss: 6.2626 - accuracy: 0.0922
# Epoch 5/300
# 899/899 [==============================] - 22s 24ms/step - loss: 6.1489 - accuracy: 0.0981
# Epoch 6/300
# 899/899 [==============================] - 21s 24ms/step - loss: 6.0414 - accuracy: 0.1035
# Epoch 7/300
# 899/899 [==============================] - 20s 23ms/step - loss: 5.9290 - accuracy: 0.1079
# Epoch 8/300
# 899/899 [==============================] - 20s 23ms/step - loss: 5.8229 - accuracy: 0.1121
# Epoch 9/300
# 899/899 [==============================] - 20s 23ms/step - loss: 5.7185 - accuracy: 0.1146
# Epoch 10/300
# 899/899 [==============================] - 21s 23ms/step - loss: 5.6146 - accuracy: 0.1166
# Epoch 11/300
# 899/899 [==============================] - 21s 23ms/step - loss: 5.5211 - accuracy: 0.1185
# Epoch 12/300
# 899/899 [==============================] - 20s 22ms/step - loss: 5.4174 - accuracy: 0.1210
# Epoch 13/300
# 899/899 [==============================] - 21s 23ms/step - loss: 5.3226 - accuracy: 0.1220
# Epoch 14/300
# 899/899 [==============================] - 20s 22ms/step - loss: 5.2334 - accuracy: 0.1245
# Epoch 15/300
# 899/899 [==============================] - 20s 23ms/step - loss: 5.1485 - accuracy: 0.1267
# Epoch 16/300
# 899/899 [==============================] - 20s 22ms/step - loss: 5.0668 - accuracy: 0.1288
# Epoch 17/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.9896 - accuracy: 0.1306
# Epoch 18/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.9163 - accuracy: 0.1331
# Epoch 19/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.8492 - accuracy: 0.1352
# Epoch 20/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.7815 - accuracy: 0.1394
# Epoch 21/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.7198 - accuracy: 0.1421
# Epoch 22/300
# 899/899 [==============================] - 21s 23ms/step - loss: 4.6639 - accuracy: 0.1453
# Epoch 23/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.6092 - accuracy: 0.1484
# Epoch 24/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.5610 - accuracy: 0.1518
# Epoch 25/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.5140 - accuracy: 0.1566
# Epoch 26/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.4681 - accuracy: 0.1594
# Epoch 27/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.4284 - accuracy: 0.1629
# Epoch 28/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.3853 - accuracy: 0.1670
# Epoch 29/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.3474 - accuracy: 0.1706
# Epoch 30/300
# 899/899 [==============================] - 21s 23ms/step - loss: 4.3078 - accuracy: 0.1753
# Epoch 31/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.2732 - accuracy: 0.1782
# Epoch 32/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.2378 - accuracy: 0.1810
# Epoch 33/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.2057 - accuracy: 0.1839
# Epoch 34/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.1757 - accuracy: 0.1889
# Epoch 35/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.1970 - accuracy: 0.1861
# Epoch 36/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.1253 - accuracy: 0.1947
# Epoch 37/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.9276 - accuracy: 0.1575
# Epoch 38/300
# 899/899 [==============================] - 20s 23ms/step - loss: 5.5877 - accuracy: 0.1265
# Epoch 39/300
# 899/899 [==============================] - 20s 22ms/step - loss: 5.1794 - accuracy: 0.1372
# Epoch 40/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.8237 - accuracy: 0.1465
# Epoch 41/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.6257 - accuracy: 0.1568
# Epoch 42/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.6532 - accuracy: 0.1500
# Epoch 43/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.6177 - accuracy: 0.1460
# Epoch 44/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.4878 - accuracy: 0.1567
# Epoch 45/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.4006 - accuracy: 0.1649
# Epoch 46/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.3256 - accuracy: 0.1723
# Epoch 47/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.2640 - accuracy: 0.1795
# Epoch 48/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.2025 - accuracy: 0.1861
# Epoch 49/300
# 899/899 [==============================] - 20s 23ms/step - loss: 4.1428 - accuracy: 0.1924
# Epoch 50/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.0885 - accuracy: 0.1997
# Epoch 51/300
# 899/899 [==============================] - 20s 22ms/step - loss: 4.0362 - accuracy: 0.2063
# Epoch 52/300
# 899/899 [==============================] - 21s 23ms/step - loss: 3.9900 - accuracy: 0.2104
# Epoch 53/300
# 899/899 [==============================] - 21s 23ms/step - loss: 3.9437 - accuracy: 0.2172
# Epoch 54/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.9029 - accuracy: 0.2224
# Epoch 55/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.8609 - accuracy: 0.2271
# Epoch 56/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.8213 - accuracy: 0.2323
# Epoch 57/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.7838 - accuracy: 0.2370
# Epoch 58/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.7409 - accuracy: 0.2457
# Epoch 59/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.7081 - accuracy: 0.2484
# Epoch 60/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.6658 - accuracy: 0.2550
# Epoch 61/300
# 899/899 [==============================] - 20s 23ms/step - loss: 3.6308 - accuracy: 0.2597
# Epoch 62/300
# 899/899 [==============================] - 21s 23ms/step - loss: 3.5889 - accuracy: 0.2665
# Epoch 63/300
# 899/899 [==============================] - 20s 23ms/step - loss: 3.5560 - accuracy: 0.2703
# Epoch 64/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.5229 - accuracy: 0.2764
# Epoch 65/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.4902 - accuracy: 0.2806
# Epoch 66/300
# 899/899 [==============================] - 21s 23ms/step - loss: 3.4506 - accuracy: 0.2866
# Epoch 67/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.4172 - accuracy: 0.2916
# Epoch 68/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.3846 - accuracy: 0.2973
# Epoch 69/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.3506 - accuracy: 0.3018
# Epoch 70/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.3152 - accuracy: 0.3074
# Epoch 71/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.2842 - accuracy: 0.3123
# Epoch 72/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.2472 - accuracy: 0.3180
# Epoch 73/300
# 899/899 [==============================] - 20s 23ms/step - loss: 3.2173 - accuracy: 0.3237
# Epoch 74/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.1874 - accuracy: 0.3276
# Epoch 75/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.1592 - accuracy: 0.3323
# Epoch 76/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.1260 - accuracy: 0.3372
# Epoch 77/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.0953 - accuracy: 0.3417
# Epoch 78/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.0686 - accuracy: 0.3461
# Epoch 79/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.0389 - accuracy: 0.3515
# Epoch 80/300
# 899/899 [==============================] - 20s 22ms/step - loss: 3.0063 - accuracy: 0.3551
# Epoch 81/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.9777 - accuracy: 0.3608
# Epoch 82/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.9515 - accuracy: 0.3655
# Epoch 83/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.9207 - accuracy: 0.3704
# Epoch 84/300
# 899/899 [==============================] - 20s 23ms/step - loss: 2.8910 - accuracy: 0.3749
# Epoch 85/300
# 899/899 [==============================] - 20s 23ms/step - loss: 2.8581 - accuracy: 0.3804
# Epoch 86/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.8335 - accuracy: 0.3855
# Epoch 87/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.8101 - accuracy: 0.3881
# Epoch 88/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.7780 - accuracy: 0.3935
# Epoch 89/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.7483 - accuracy: 0.3988
# Epoch 90/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.7254 - accuracy: 0.4019
# Epoch 91/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.6971 - accuracy: 0.4089
# Epoch 92/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.6691 - accuracy: 0.4122
# Epoch 93/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.6457 - accuracy: 0.4168
# Epoch 94/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.6187 - accuracy: 0.4204
# Epoch 95/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.5890 - accuracy: 0.4250
# Epoch 96/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.5604 - accuracy: 0.4314
# Epoch 97/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.5419 - accuracy: 0.4340
# Epoch 98/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.5189 - accuracy: 0.4361
# Epoch 99/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.4861 - accuracy: 0.4429
# Epoch 100/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.4616 - accuracy: 0.4487
# Epoch 101/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.4389 - accuracy: 0.4520
# Epoch 102/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.4136 - accuracy: 0.4563
# Epoch 103/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.3950 - accuracy: 0.4594
# Epoch 104/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.3691 - accuracy: 0.4641
# Epoch 105/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.3447 - accuracy: 0.4685
# Epoch 106/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.3226 - accuracy: 0.4721
# Epoch 107/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.2945 - accuracy: 0.4786
# Epoch 108/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.2738 - accuracy: 0.4818
# Epoch 109/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.2510 - accuracy: 0.4845
# Epoch 110/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.2304 - accuracy: 0.4892
# Epoch 111/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.2070 - accuracy: 0.4939
# Epoch 112/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.1837 - accuracy: 0.4984
# Epoch 113/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.1654 - accuracy: 0.5016
# Epoch 114/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.1390 - accuracy: 0.5067
# Epoch 115/300
# 899/899 [==============================] - 20s 23ms/step - loss: 2.1161 - accuracy: 0.5113
# Epoch 116/300
# 899/899 [==============================] - 20s 23ms/step - loss: 2.0921 - accuracy: 0.5150
# Epoch 117/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.0777 - accuracy: 0.5181
# Epoch 118/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.0579 - accuracy: 0.5221
# Epoch 119/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.0307 - accuracy: 0.5269
# Epoch 120/300
# 899/899 [==============================] - 20s 22ms/step - loss: 2.0141 - accuracy: 0.5294
# Epoch 121/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.9920 - accuracy: 0.5342
# Epoch 122/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.9659 - accuracy: 0.5402
# Epoch 123/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.9543 - accuracy: 0.5411
# Epoch 124/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.9314 - accuracy: 0.5460
# Epoch 125/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.9050 - accuracy: 0.5523
# Epoch 126/300
# 899/899 [==============================] - 20s 23ms/step - loss: 1.8956 - accuracy: 0.5531
# Epoch 127/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.8827 - accuracy: 0.5545
# Epoch 128/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.8641 - accuracy: 0.5588
# Epoch 129/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.8336 - accuracy: 0.5657
# Epoch 130/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.8210 - accuracy: 0.5675
# Epoch 131/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.8051 - accuracy: 0.5699
# Epoch 132/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.7919 - accuracy: 0.5730
# Epoch 133/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.7725 - accuracy: 0.5762
# Epoch 134/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.7435 - accuracy: 0.5835
# Epoch 135/300
# 899/899 [==============================] - 21s 23ms/step - loss: 1.7351 - accuracy: 0.5852
# Epoch 136/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.7154 - accuracy: 0.5877
# Epoch 137/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.7017 - accuracy: 0.5906
# Epoch 138/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6786 - accuracy: 0.5958
# Epoch 139/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6695 - accuracy: 0.5970
# Epoch 140/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6481 - accuracy: 0.6018
# Epoch 141/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6338 - accuracy: 0.6043
# Epoch 142/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6258 - accuracy: 0.6062
# Epoch 143/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.6067 - accuracy: 0.6106
# Epoch 144/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5779 - accuracy: 0.6162
# Epoch 145/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5653 - accuracy: 0.6184
# Epoch 146/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5674 - accuracy: 0.6187
# Epoch 147/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5474 - accuracy: 0.6216
# Epoch 148/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5270 - accuracy: 0.6255
# Epoch 149/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.5123 - accuracy: 0.6319
# Epoch 150/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4983 - accuracy: 0.6322
# Epoch 151/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4842 - accuracy: 0.6357
# Epoch 152/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4595 - accuracy: 0.6401
# Epoch 153/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4466 - accuracy: 0.6434
# Epoch 154/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4343 - accuracy: 0.6463
# Epoch 155/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4373 - accuracy: 0.6425
# Epoch 156/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4092 - accuracy: 0.6503
# Epoch 157/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.4221 - accuracy: 0.6486
# Epoch 158/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3810 - accuracy: 0.6575
# Epoch 159/300
# 899/899 [==============================] - 20s 23ms/step - loss: 1.3619 - accuracy: 0.6613
# Epoch 160/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3606 - accuracy: 0.6610
# Epoch 161/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3365 - accuracy: 0.6671
# Epoch 162/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3367 - accuracy: 0.6663
# Epoch 163/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3152 - accuracy: 0.6704
# Epoch 164/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3108 - accuracy: 0.6721
# Epoch 165/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.3029 - accuracy: 0.6728
# Epoch 166/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2841 - accuracy: 0.6786
# Epoch 167/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2714 - accuracy: 0.6811
# Epoch 168/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2650 - accuracy: 0.6815
# Epoch 169/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2461 - accuracy: 0.6867
# Epoch 170/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2402 - accuracy: 0.6872
# Epoch 171/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2335 - accuracy: 0.6878
# Epoch 172/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.2214 - accuracy: 0.6899
# Epoch 173/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1996 - accuracy: 0.6964
# Epoch 174/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1922 - accuracy: 0.6976
# Epoch 175/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1882 - accuracy: 0.6977
# Epoch 176/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1866 - accuracy: 0.6985
# Epoch 177/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1691 - accuracy: 0.7013
# Epoch 178/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1464 - accuracy: 0.7075
# Epoch 179/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1459 - accuracy: 0.7077
# Epoch 180/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1404 - accuracy: 0.7073
# Epoch 181/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1232 - accuracy: 0.7116
# Epoch 182/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1120 - accuracy: 0.7151
# Epoch 183/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.1052 - accuracy: 0.7169
# Epoch 184/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0983 - accuracy: 0.7185
# Epoch 185/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0996 - accuracy: 0.7167
# Epoch 186/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0778 - accuracy: 0.7225
# Epoch 187/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0672 - accuracy: 0.7239
# Epoch 188/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0499 - accuracy: 0.7281
# Epoch 189/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0425 - accuracy: 0.7302
# Epoch 190/300
# 899/899 [==============================] - 20s 23ms/step - loss: 1.0523 - accuracy: 0.7280
# Epoch 191/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0346 - accuracy: 0.7311
# Epoch 192/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0237 - accuracy: 0.7344
# Epoch 193/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0205 - accuracy: 0.7347
# Epoch 194/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0169 - accuracy: 0.7346
# Epoch 195/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9911 - accuracy: 0.7431
# Epoch 196/300
# 899/899 [==============================] - 20s 22ms/step - loss: 1.0128 - accuracy: 0.7360
# Epoch 197/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9901 - accuracy: 0.7424
# Epoch 198/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9718 - accuracy: 0.7471
# Epoch 199/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9661 - accuracy: 0.7484
# Epoch 200/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9570 - accuracy: 0.7500
# Epoch 201/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9425 - accuracy: 0.7537
# Epoch 202/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9573 - accuracy: 0.7494
# Epoch 203/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9388 - accuracy: 0.7537
# Epoch 204/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9228 - accuracy: 0.7584
# Epoch 205/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9313 - accuracy: 0.7549
# Epoch 206/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9036 - accuracy: 0.7623
# Epoch 207/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9098 - accuracy: 0.7606
# Epoch 208/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8992 - accuracy: 0.7624
# Epoch 209/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8964 - accuracy: 0.7643
# Epoch 210/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.9083 - accuracy: 0.7607
# Epoch 211/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8760 - accuracy: 0.7693
# Epoch 212/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8744 - accuracy: 0.7673
# Epoch 213/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8767 - accuracy: 0.7682
# Epoch 214/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8571 - accuracy: 0.7727
# Epoch 215/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8665 - accuracy: 0.7705
# Epoch 216/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8514 - accuracy: 0.7736
# Epoch 217/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8313 - accuracy: 0.7786
# Epoch 218/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8531 - accuracy: 0.7729
# Epoch 219/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8527 - accuracy: 0.7714
# Epoch 220/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8065 - accuracy: 0.7852
# Epoch 221/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8320 - accuracy: 0.7778
# Epoch 222/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8278 - accuracy: 0.7792
# Epoch 223/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8010 - accuracy: 0.7860
# Epoch 224/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8042 - accuracy: 0.7851
# Epoch 225/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.8025 - accuracy: 0.7847
# Epoch 226/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7837 - accuracy: 0.7895
# Epoch 227/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7835 - accuracy: 0.7903
# Epoch 228/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7844 - accuracy: 0.7898
# Epoch 229/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7663 - accuracy: 0.7955
# Epoch 230/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7842 - accuracy: 0.7890
# Epoch 231/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7737 - accuracy: 0.7916
# Epoch 232/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7575 - accuracy: 0.7953
# Epoch 233/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7425 - accuracy: 0.7996
# Epoch 234/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7618 - accuracy: 0.7935
# Epoch 235/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7692 - accuracy: 0.7913
# Epoch 236/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7529 - accuracy: 0.7963
# Epoch 237/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7085 - accuracy: 0.8088
# Epoch 238/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7210 - accuracy: 0.8049
# Epoch 239/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7216 - accuracy: 0.8056
# Epoch 240/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7257 - accuracy: 0.8027
# Epoch 241/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7208 - accuracy: 0.8048
# Epoch 242/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7279 - accuracy: 0.8023
# Epoch 243/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.7177 - accuracy: 0.8050
# Epoch 244/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6875 - accuracy: 0.8137
# Epoch 245/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6949 - accuracy: 0.8094
# Epoch 246/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6894 - accuracy: 0.8123
# Epoch 247/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6990 - accuracy: 0.8096
# Epoch 248/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6783 - accuracy: 0.8153
# Epoch 249/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6777 - accuracy: 0.8140
# Epoch 250/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6978 - accuracy: 0.8079
# Epoch 251/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6632 - accuracy: 0.8198
# Epoch 252/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6603 - accuracy: 0.8189
# Epoch 253/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6600 - accuracy: 0.8186
# Epoch 254/300
# 795/899 [=========================>....] - ETA: 2s - loss: 0.6630 - accuracy: 0.8186
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 899/899 [==============================] - 20s 23ms/step - loss: 0.6429 - accuracy: 0.8223
# Epoch 264/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6012 - accuracy: 0.8343
# Epoch 265/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.6209 - accuracy: 0.8301
# Epoch 266/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.6335 - accuracy: 0.8242
# Epoch 267/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6116 - accuracy: 0.8321
# Epoch 268/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.6353 - accuracy: 0.8255
# Epoch 269/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.6185 - accuracy: 0.8298
# Epoch 270/300
# 899/899 [==============================] - 21s 23ms/step - loss: 0.6122 - accuracy: 0.8306
# Epoch 271/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.5970 - accuracy: 0.8353
# Epoch 272/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.5841 - accuracy: 0.8392
# Epoch 273/300
# 325/899 [=========>....................] - ETA: 12s - loss: 0.5509 - accuracy: 0.8498
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 899/899 [==============================] - 20s 23ms/step - loss: 0.5642 - accuracy: 0.8428
# Epoch 281/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5786 - accuracy: 0.8397
# Epoch 282/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5775 - accuracy: 0.8404
# Epoch 283/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5706 - accuracy: 0.8413
# Epoch 284/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5469 - accuracy: 0.8472
# Epoch 285/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5537 - accuracy: 0.8453
# Epoch 286/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5809 - accuracy: 0.8373
# Epoch 287/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5366 - accuracy: 0.8498
# Epoch 288/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5529 - accuracy: 0.8447
# Epoch 289/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5552 - accuracy: 0.8437
# Epoch 290/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5619 - accuracy: 0.8440
# Epoch 291/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5528 - accuracy: 0.8447
# Epoch 292/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.5340 - accuracy: 0.8512
# Epoch 293/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5444 - accuracy: 0.8472
# Epoch 294/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5633 - accuracy: 0.8421
# Epoch 295/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5322 - accuracy: 0.8511
# Epoch 296/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5123 - accuracy: 0.8565
# Epoch 297/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5246 - accuracy: 0.8530
# Epoch 298/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5253 - accuracy: 0.8528
# Epoch 299/300
# 899/899 [==============================] - 20s 22ms/step - loss: 0.5604 - accuracy: 0.8411
# Epoch 300/300
# 899/899 [==============================] - 20s 23ms/step - loss: 0.5226 - accuracy: 0.8541

# %%
# save the model to file
#model.save('epochBIG.h5')
# save the tokenizer
#dump(tokenizer, open('epochBIG', 'wb'))

# %% [markdown]
# # Generating New Text

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''
    
    # Final Output
    output_text = []
    
    # Intial Seed Sequence
    input_text = seed_text
    
    # Create num_gen_words
    for i in range(num_gen_words):
        
        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        
        # Pad sequences to our trained rate (50 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')
        
        # Predict Class Probabilities for each word
        predictions = model.predict(pad_encoded, verbose=0)
        
        # Grab word
        pred_word_ind = np.argmax(predictions[0])
        pred_word = tokenizer.index_word[pred_word_ind] 
        
        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word
        
        output_text.append(pred_word)
        
    # Make it look like a sentence.
    return ' '.join(output_text)

# %% [markdown]
# ### Grab a random seed sequence

# %%
text_sequences[0]
# Out:
# ['chapter',
#  '1',
#  'loomings',
#  'call',
#  'me',
#  'ishmael',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to']

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['he',
#  'recognised',
#  'his',
#  'cutting',
#  'spade',
#  'pole',
#  'entangled',
#  'in',
#  'the',
#  'lines',
#  'that',
#  'were',
#  'knotted',
#  'round',
#  'the',
#  'tail',
#  'of',
#  'one',
#  'of',
#  'these',
#  'whales',
#  'there',
#  "'s",
#  'a',
#  'pretty',
#  'fellow']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# "he recognised his cutting spade pole entangled in the lines that were knotted round the tail of one of these whales there 's a pretty fellow"

# %%
generated_text = generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=25)
print(generated_text)
# Out:
# 's crew now i heard one hundred from all the planks with him to lighten her over a living point of hydrus and the cheerful

# %% [markdown]
# ### Exploring Generated Sequence

# %%
final_text = seed_text + generated_text
print(final_text)
# Out:
# he recognised his cutting spade pole entangled in the lines that were knotted round the tail of one of these whales there 's a pretty fellow's crew now i heard one hundred from all the planks with him to lighten her over a living point of hydrus and the cheerful
